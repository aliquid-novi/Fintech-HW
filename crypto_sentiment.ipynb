# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

# %%
# !pip install python-dotenv
# !pip install newsapi-python
# Out:
# Requirement already satisfied: python-dotenv in c:\users\markp\anaconda3\lib\site-packages (0.19.1)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\markp\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: newsapi-python in c:\users\markp\anaconda3\lib\site-packages (0.2.6)
# Requirement already satisfied: requests<3.0.0 in c:\users\markp\anaconda3\lib\site-packages (from newsapi-python) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (1.26.7)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\markp\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Read your api key environment variable
load_dotenv()
from newsapi import NewsApiClient
api_key = os.getenv('NEWS_API')
type(api_key)
# Out:
# str

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"bitcoin: {bitcoin_headlines['totalResults']}")

# Show sample article
bitcoin_headlines["articles"][0]
# Out:
# bitcoin: 7339
# {'source': {'id': None, 'name': 'Lifehacker.com'},
#  'author': 'Jeff Somers',
#  'title': 'Is the Crypto Bubble Going to Burst?',
#  'description': 'Even if you aren’t paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 trillion last year to about $1.5 trillion in a matter of days…',
#  'url': 'https://lifehacker.com/is-the-crypto-bubble-going-to-burst-1848475768',
#  'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/976a59b09e0e681e692bd7517498e3f2.jpg',
#  'publishedAt': '2022-02-09T16:00:00Z',
#  'content': 'Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 tr… [+4782 chars]'}

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_articles = newsapi.get_everything(q='ethereum',
                                      language='en',
                                      sort_by='relevancy',
                                     page_size=100)
eth_articles['totalResults']

# Print total articles
print(f"ethereum: {ethereum_headlines['totalResults']}")

# Show sample article
ethereum_headlines["articles"][0]
# Out:
# ethereum: 3047
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Omar L. Gallaga',
#  'title': 'Playing With Crypto? You’ll Need a Wallet (or Several)',
#  'description': 'Buying and selling NFTs or transferring digital currency is going to require a little leap of faith. Here’s how to get started.',
#  'url': 'https://www.wired.com/story/how-to-choose-set-up-crypto-wallet/',
#  'urlToImage': 'https://media.wired.com/photos/620415899266d5d11c07b346/191:100/w_1280,c_limit/Gear-Coinbase-App-Screens.jpg',
#  'publishedAt': '2022-02-10T14:00:00Z',
#  'content': "If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there'd be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars]"}

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-02-09  Even if you arent paying attention to Bitcoin ...    0.5859
# 1  2022-02-11  Netflix\r\n is making a docuseries about one o...   -0.7096
# 2  2022-02-08  Over the last five years, about 25,000 of thos...   -0.4939
# 3  2022-02-17  Even in cyberspace, the Department of Justice ...    0.7351
# 4  2022-02-13  The couple would never flee from the country a...   -0.3400
#
#    positive  negative  neutral
# 0     0.124     0.000    0.876
# 1     0.000     0.169    0.831
# 2     0.000     0.091    0.909
# 3     0.147     0.000    0.853
# 4     0.057     0.118    0.825

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-02-10  If people who buy cryptocurrencies intended on...   -0.2023
# 1  2022-03-01  In February, shit hit the fan in the usual way...   -0.3182
# 2  2022-02-17  Technical analysis isnt a perfect tool, but it...   -0.2498
# 3  2022-02-09  This enables an L1 platform to bootstrap its n...    0.0000
# 4  2022-02-25  Coinbase reported that the share of trading vo...    0.6705
#
#    positive  negative  neutral
# 0     0.039     0.062    0.899
# 1     0.059     0.093    0.848
# 2     0.000     0.059    0.941
# 3     0.000     0.000    1.000
# 4     0.188     0.000    0.812

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound   positive    negative     neutral
# count  100.000000  100.00000  100.000000  100.000000
# mean     0.054023    0.06928    0.056660    0.874070
# std      0.470294    0.06223    0.073662    0.085674
# min     -0.895700    0.00000    0.000000    0.627000
# 25%     -0.301550    0.00000    0.000000    0.818250
# 50%      0.038600    0.06600    0.000000    0.884000
# 75%      0.476700    0.11925    0.091500    0.938000
# max      0.834100    0.23400    0.269000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#          Compound    Negative     Neutral   Positive
# count  100.000000  100.000000  100.000000  100.00000
# mean     0.210204    0.034990    0.876600    0.08839
# std      0.417609    0.060181    0.085037    0.07208
# min     -0.913600    0.000000    0.627000    0.00000
# 25%      0.000000    0.000000    0.835250    0.04050
# 50%      0.214300    0.000000    0.875000    0.07400
# 75%      0.510600    0.059000    0.941500    0.12700
# max      0.918600    0.312000    1.000000    0.29000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum (85%)
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer

lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
def process_text(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', article)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
def get(api_key):
    global token

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    words = [t.translate(str.maketrans('','',string.punctuation)) for t in tokens]

   
    # Create a tokenized list of the words
    tokens = word_tokenize(re_clean)
    
    
    # Lemmatize words into root words
    tokens = ', '.join([lemmatizer.lemmatize(word) for word in words])

   
    # Convert the words to lowercase
    tokens = [t.lower() for t in tokens]
    
    # Remove the stop words
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
global tokens
bitcoin_df["tokens"]= bitcoin_df['text'].apply(tokenizer)
bitcoin_df.head()

# %%
# Create a new tokens column for Ethereum
eth_df["tokens"] = eth_df['text'].apply(tokenizer)
eth_df.head()

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
tokens_btc = []
tokens_btc_all = []
for x in range(0,100):
    tokens_btc = bitcoin_df["tokens"].values[x]
    tokens_btc_all.append(tokens_btc)

# %%
# Generate the Ethereum N-grams where N=2
tokens_eth = []
tokens_eth_all = []
for x in range(0,100):
    tokens_eth = ethereum_df["tokens"].values[x]
    tokens_eth_all.append(tokens_eth)
flattened_eth = [val for sublist in tokens_eth_all for val in sublist]
bigram_counts = Counter(ngrams(flattened_eth, n=2))
print(dict(bigram_counts))

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
N=2
bigram_counts_B = Counter(ngrams(bitcoin_p, N))
print(dict(bigram_counts_B))

# %%
# Use token_count to get the top 10 words for Ethereum
N= 2
bigram_counts_E = Counter(ngrams(ethereum_p, N))
print(dict(bigram_counts_E))

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)
big_string = ' '.join(flattened_btc)
input_text = process_text(big_string)
wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
big_string = ' '.join(flattened_eth)
input_text = process_text(big_string)
wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
# 2022-03-06 05:43:16.653771: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-03-06 05:43:16.653832: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\markp\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\markp\anaconda3\python.exe -m pip install --upgrade pip' command.
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\markp\anaconda3\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: jinja2 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: setuptools in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (60.0.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.21.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\markp\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\markp\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\markp\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\markp\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\markp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: colorama in c:\users\markp\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\markp\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\markp\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_concat_bitcoin = bitcoin_df.text.str.cat()
all_concat_bitcoin
# Out:
# 'Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 tr… [+4782 chars]Netflix\r\n is making a docuseries about one of the worst rappers of all time\r\n. Coincidentally, Heather "Razzlekhan" Morgan and her husband, Ilya Lichtenstein, were charged this week with conspiring t… [+1432 chars]Over the last five years, about 25,000 of those Bitcoin were transferred out of Mr. Lichtensteins wallet using a complicated series of transactions meant to obscure that the currency had been stolen … [+2506 chars]Even in cyberspace, the Department of Justice is able to use a tried and true investigative technique, following the money, Ms. Monaco said. Its what led us to Al Capone in the 30s. It helped us dest… [+1176 chars]The couple would never flee from the country at the risk of losing access to their ability to have children, the lawyer wrote.\r\nAt the hearing, a prosecutor, Margaret Lynaugh, said in opposing bail f… [+1600 chars]If Sundays Super Bowl ads are any indication, crypto has truly arrived in mainstream culture. And if you didnt catch the game, you can watch the ads here, featuring Larry David, LeBron James, and a Q… [+3454 chars]The news of one of the biggest money laundering schemes in history captivated the world on Tuesday, not so much because of the crimewhich involved $4.5 billion in bitcoin and is, yeah, a big dealbut … [+1948 chars]The confiscation of the Bitcoin that remained in Mr. Lichtensteins wallet on Feb. 1, worth roughly $3.6 billion at the time, was the Justice Departments largest financial seizure ever, officials have… [+1442 chars]In one 2020 article for the magazine, she explored how to protect your business as cybercriminals and fraudsters are taking advantage of disruptions caused by the pandemic.\r\nFor Inc.s entrepreneurial… [+1705 chars]If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there\'d be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars]Feb 4 (Reuters) - Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 23.2% from the ye… [+321 chars]Feb 22 (Reuters) - Bitcoin miners are feeling the heat - and the pain\'s rippling downstream to pressure prices.\r\nThe cryptocurrency\'s spectacular rally in 2021 drew thousands of entrants into mining,… [+4196 chars]March 1 (Reuters) - Bitcoin has leapt since Russia\'s invasion of Ukraine, bolstered by people in those countries looking to store and move money in anonymous and decentralised crypto.\r\nBitcoin tradin… [+3955 chars]Getty\r\nWelcome to Nonfungible Tidbits. Our focus this week: Russia\'s war in Ukraine.\xa0\r\nIn addition to uprooting the lives of Ukrainians and throwing the international order into chaos, the Russian in… [+3275 chars]An appeals court decided shilling for an unregistered security on YouTube is the same thing as doing it in a letter.\r\nIllustration by Alex Castro / The Verge\r\nThe story of BitConnect doesnt include a… [+3046 chars]Nurphoto/Getty\r\nAs Russia launched an invasion into his home country last Thursday, Ukranian photographer Vitaliy Raskalov found himself a world away in Mexico City. When I spoke with him over Telegr… [+7815 chars]Read enough about Bitcoin, and youll inevitably come across people who refer to the cryptocurrency as a religion.\r\nBloombergs Lorcan Roche Kelly called Bitcoin the first true religion of the 21st cen… [+8156 chars]Feb 15 (Reuters) - Bristling tensions and looming laws in Europe could offer clues to two questions: Can bitcoin be a safe-haven asset? And can Russia emerge as a crypto superpower?\r\nThe answer to th… [+4123 chars]LONDON, March 4 (Reuters) - Cryptocurrencies have been close to the headlines since Russia invaded Ukraine, wit ...

# %%
# Run the NER processor on all of the text
bitcoin_doc = nlp(all_concat_bitcoin)
bitcoin_doc

# Add a title to the document
bitcoin_doc.user_data["Title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with the total value of the market tumbling from a high of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br> is making a docuseries
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>. Coincidentally, Heather &quot;Razzlekhan&quot; Morgan and her husband,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ilya Lichtenstein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , were charged
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with conspiring t… [+1432 chars]Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last five years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 25,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of those Bitcoin were transferred out of Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lichtensteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wallet using a complicated series of transactions meant to obscure that the currency had been stolen … [+2506 chars]Even in cyberspace,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is able to use a tried and true investigative technique, following the money, Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monaco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. Its what led us to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Al Capone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br>At the hearing, a prosecutor,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Margaret Lynaugh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , said in opposing bail f… [+1600 chars]If Sundays
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Super Bowl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  ads are any indication, crypto has truly arrived in mainstream culture. And if you didnt catch the game, you can watch the ads here, featuring
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry David
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LeBron James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and a Q… [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3454
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars]The news of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the biggest money laundering schemes in history captivated the world on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , not so much because of the crimewhich involved
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $4.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in bitcoin and is, yeah, a big dealbut … [+1948 chars]The confiscation of the Bitcoin that remained in Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lichtensteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wallet on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Feb. 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $3.6 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>

# %%
# List all Entities
for i in bitcoin_doc.ents:
    print(i.text, i.label_)
# Out:
# last week DATE
# 3 MONEY
# about one CARDINAL
# Ilya Lichtenstein PERSON
# this week DATE
# the last five years DATE
# about 25,000 CARDINAL
# Lichtensteins PERSON
# the Department of Justice ORG
# Monaco PERSON
# Al Capone LOC
# Margaret Lynaugh PERSON
# Super Bowl EVENT
# Larry David PERSON
# LeBron James PERSON
# +3454 ORG
# one CARDINAL
# Tuesday DATE
# $4.5 billion MONEY
# Lichtensteins PERSON
# Feb. 1 DATE
# roughly $3.6 billion MONEY
# one 2020 DATE
# 4 DATE
# Reuters ORG
# 8.82% PERCENT
# 40,611.4 MONEY
# 2202 DATE
# Friday DATE
# 3,291.29 MONEY
# Bitcoin PERSON
# 23.2% PERCENT
# 22 CARDINAL
# Reuters ORG
# 2021 DATE
# thousands CARDINAL
# Reuters ORG
# Russia GPE
# Ukraine GPE
# Nonfungible Tidbits PERSON
# this week DATE
# Russia GPE
# Ukraine GPE
# Ukrainians NORP
# Russian NORP
# YouTube ORG
# Alex Castro PERSON
# Verge ORG
# BitConnect ORG
# Getty GPE
# Russia GPE
# last Thursday DATE
# Ukranian NORP
# Mexico City GPE
# Telegr ORG
# Bitcoin WORK_OF_ART
# Bloombergs Lorcan Roche Kelly ORG
# first ORDINAL
# the 21st cen DATE
# 15 CARDINAL
# Reuters ORG
# Europe LOC
# two CARDINAL
# Russia GPE
# March 4 DATE
# Reuters ORG
# Russia GPE
# Ukraine GPE
# Russia GPE
# 8 CARDINAL
# Reuters ORG
# 2022 DATE
# Feb 11 DATE
# Reuters ORG
# Federal Reserve ORG
# 11 CARDINAL
# Reuters ORG
# Intel Corp ORG
# Friday DATE
# U.S. Justice Department ORG
# Tuesday DATE
# $3.6 billion MONEY
# 2016 DATE
# chars]NEW YORK GPE
# Feb 9 DATE
# Tuesday DATE
# Ilya Dutch Lich ORG
# Reuters ORG
# BITCOIN PERSON
# Ukrainian NORP
# Tom Lee PERSON
# Ukraine GPE
# a year DATE
# $20 million MONEY
# $220 million MONEY
# CoinDesk ORG
# Intelligence ORG
# Shark Tank WORK_OF_ART
# Kevin O'Leary's PERSON
# 100,000 MONEY
# 200,000 MONEY
# 300,000 MONEY
# two-week DATE
# Tuesday DATE
# Russians NORP
# Ukrainians NORP
# Feb 20 DATE
# Reuters ORG
# El Salvador GPE
# Nayib Bukele PERSON
# Sunday DATE
# Congress ORG
# Central American NORP
# the past 12 years DATE
# Anthony Welch PERSON
# Theresa PERSON
# Robinson Crusoe ORG
# South Pacific LOC
# Welch ORG
# British NORP
# millions of dollars MONEY
# Canadian NORP
# Canadians NORP
# one CARDINAL
# Satish Kumbhani PERSON
# BitConnect ORG
# last week DATE
# $2.4 billion MONEY
# Ponzi ORG
# James Bareham PERSON
# More than $15 million MONEY
# More than $15 million MONEY
# Ukrainian GPE
# Russia GPE
# Montana GPE
# years DATE
# one CARDINAL
# 24 CARDINAL
# Reuters ORG
# Thursday DATE
# Feb 8 DATE
# Reuters ORG
# Ukrainian GPE
# Feb 25 DATE
# Reuters ORG
# Ukrainian NORP
# $4 million MONEY
# Russia GPE
# Thursday DATE
# Feb 27 DATE
# Reuters ORG
# Ukraine GPE
# almost $8 million MONEY
# today DATE
# Colorado GPE
# the middle of this year DATE
# US GPE
# Jared Polis PERSON
# late 2024 DATE
# one CARDINAL
# Hu PERSON
# Ukrainian NORP
# more than $4 million MONEY
# Russia GPE
# Elliptic LOC
# Mike Novogratz PERSON
# $3.6 billion MONEY
# 2016 DATE
# Bitfinex ORG
# last year DATE
# Between 2020 and 2021 DATE
# Russians NORP
# Mark Mobius PERSON
# Russia GPE
# Ukraine GPE
# Thursday DATE
# US GPE
# Brett Harrison PERSON
# Bitcoin PERSON
# Vladimir Putin PERSON
# Heinemeier Hansson PERSON
# Twitter PRODUCT
# Monday DATE
# Steven Vaughan-Nichols PERSON
# Linus Torvalds ORG
# Satoshi Nakamoto PERSON
# first ORDINAL
# early this week DATE
# Ukraine GPE
# Russian NORP
# 40,000 MONEY
# the weekend DATE
# this weeks DATE
# Marina Hyde PERSON
# London GPE
# Zoe Williams PERSON
# Charlie Brooker PERSON
# Annie PERSON
# 19m11s CARDINAL
# Luke Winkie PERSON
# Russia GPE
# Ukraine GPE
# chars]NEW YORK GPE
# Feb 24 DATE
# Reuters ORG
# U.S. GPE
# Thursday DATE
# ATM ORG
# Los Angeles GPE
# The Justice Department ORG
# New York GPE
# billions of dollars MONEY
# Feb 23 DATE
# Reuters Breakingviews ORG
# this year DATE
# billions CARDINAL
# Feb 28 DATE
# Reuters ORG
# Russian NORP
# Tether ORG
# Monday DATE
# Feb 8 DATE
# Reuters ORG
# chars]MEXICO CITY GPE
# Feb 16 DATE
# Reuters ORG
# Nayib Bukele PERSON
# Wednesday DATE
# U.S. GPE
# El Salvador's GPE
# the last few days DATE
# Cities: Skylines ORG
# Thursday, December 17, 2021 DATE
# 47 CARDINAL
# 35 CARDINAL
# 12:24 pm TIME
# January 11 DATE
# Reese Witherspoon PERSON
# US GPE
# 3.6bn MONEY
# 2016 CARDINAL
# New York GPE
# last week DATE
# 3.6bn MONEY
# the century DATE
# US GPE
# Bitcoin and Ethereum ORG
# Feb 8 DATE
# Reuters ORG
# FBI ORG
# Tuesday DATE
# morning TIME
# 2016 DATE
# Bitfinex ORG
# chars]NEW YORK GPE
# March 4 DATE
# Reuters ORG
# U.S. GPE
# the latest week DATE
# mid-August 2021 DATE
# Reuters ORG
# U.S. GPE
# Knox PERSON
# Lohstroh ORG
# West LOC
# Russia GPE
# Vladimir Putin PERSON
# Ukraine GPE
# the United States GPE
# Deutsche Bank ORG
# this week DATE
# $3.6 billion MONEY
# America GPE
# Justice Department ORG
# Ukraine GPE
# Ukraine GPE
# millions CARDINAL
# West LOC
# Monday DATE
# the previous week DATE
# Thursday DATE
# above $42,000 MONEY
# chars]ProFootball Talk ORG
# NBC Sports ORG
# Buccaneers PERSON
# Tom Brady PERSON
# June 1 DATE
# Brady PERSON
# BitConnect ORG
# $2.4 billion MONEY
# Ponzi ORG
# San Diego GPE
# chars]One day DATE
# Dara Khosrowshahi PERSON
# Bloomberg ORG
# thousands CARDINAL
# every day DATE
# Bitcoin PERSON
# Conti PERSON
# one CARDINAL
# pro-Russian NORP
# Twitter PRODUCT
# Ethereum ORG
# second ORDINAL
# two months DATE
# NFT ORG
# TIME ORG
# weekly DATE
# San Diego GPE
# BitConnect ORG
# BCC ORG
# Feb 11 DATE
# Reuters ORG
# U.S. GPE
# the latest week DATE
# mid-August 2021 DATE
# Reuters ORG
# U.S. Commodi ORG
# chars]New York GPE
# Miami GPE
# US GPE
# Bloomberg News ORG
# New Yorkers NORP
# Ted Cruz PERSON
# between $15,001 and $50,000 MONEY
# Summary</li><li> WORK_OF_ART
# Law firms</li><li> PERSON
# documents</li></ul GPE
# Feb 8 DATE
# Reuters ORG
# Canada GPE
# TMX Group ORG
# first ORDINAL
# Feb 8 DATE
# Reuters ORG
# Tuesday DATE
# U.S. GPE
# later in the week TIME
# Monday DATE
# US GPE
# Elon Musk PERSON
# Kyiv GPE
# Mykhailo Fedoro PERSON
# The Financial Stab WORK_OF_ART
# two hours TIME
# YouTube ORG
# Waka Flacka Fla ORG
# NFL ORG
# Tom Brady PERSON
# Major League Baseball ORG
# $135 million MONEY
# Europe LOC
# UK GPE
# today DATE
# CoinDesk ORG
# Russia GPE
# Ukraine GPE
# 1,940 MONEY
# Wednesday DATE
# June 202 DATE
# Blockchain LOC
# Blockchain LOC
# Tuesday DATE
# Ilya Lichtenstein PERSON
# Heather Morgan PERSON
# New York GPE
# a record $4.5 billion dollars MONEY
# the 24 hours TIME
# this week DATE
# anti-Russian NORP
# Ukraine GPE
# the US Department of Justice ORG

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
all_concat_ethereum = eth_df.text.str.cat()
all_concat_ethereum
# Out:
# 'If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there\'d be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars]In February, shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at Ethereum Name Service (ENS), a web3 business, had written the following in May 201… [+3096 chars]Technical analysis isnt a perfect tool, but it may point the way for Ethereum\r\nEthereum\xa0(ETH-USD\r\n) continues to be a volatile crypto investment. Crypto is volatile by nature Im not setting it apart … [+3612 chars]This enables an L1 platform to bootstrap its national economy over time through a flywheel between financial speculation around its native token and actual building of applications and activities in … [+4057 chars]Coinbase reported that the share of trading volume for ethereum and other altcoins increased last year, while bitcoin\'s share dropped dramatically.\xa0\r\nBetween 2020 and 2021, ethereum trading volume in… [+1187 chars]People in Colorado will be able to pay their state taxes in cryptocurrency by the middle of this year, the US state\'s governor has revealed.\r\nGov. Jared Polis laid out the timing of the move, a longt… [+2206 chars]Illustration by James Bareham / The Verge\r\n\n \n\n\n More than $15 million has been donated so far More than $15 million in cryptocurrency has been donated to Ukrainian groups since Russia attacked the c… [+7442 chars]It seems that in 2022, you cant escape from the metaverse.\xa0From Facebook to Microsoft, seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]Last night, Twitter announced itll allow users to tip accounts via Ethereum.\r\nThis is the social networks second crypto announcement in two months, after it enabled NFT-based profile pictures in Janu… [+5114 chars]Feb 7 (Reuters) - Polygon, a decentralized scaling platform for the ethereum blockchain, announced on Monday it has raised $450 million in its latest funding round led by Sequoia Capital India and in… [+1641 chars]At over two hours long, the wildly popular new YouTube documentary\xa0 "Line Goes Up The Problem With NFTs" is an exhaustive takedown of the hot new investment vehicle that everyone from Waka Flacka Fla… [+2929 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2680 chars]Feb 4 (Reuters) - Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 23.2% from the ye… [+321 chars]A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.\r\nThe Ethe… [+7320 chars]A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.\r\nLast wee… [+7988 chars]Feb 10 (Reuters) - OnlyFans, an online subscription platform known for adult content, has launched a feature for users to display verified NFTs as profile pictures, it said on Thursday.\r\nThe UK-based… [+1752 chars]Non-fungible tokens (NFTs) are the most popular digital assets today, capturing the attention of cryptocurrency investors, whales and people from around the world. People find it amazing that some us… [+6463 chars]Bitcoin\'s dominance in cryptocurrencies will dwindle as tokens using a proof-of-stake system eat away at its market share, FTX.US boss Brett Harrison has predicted.\r\nBitcoin\'s grip is loosening as th… [+3022 chars]Most online images are just a right-click away from being in someones personal collection. Theyre f ...

# %%
# Run the NER processor on all of the text
ethereum_doc = nlp(all_concat_ethereum)
ethereum_doc

# Add a title to the document
ethereum_doc.user_data["Title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there'd be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars]In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Name Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a web3 business, had written the following in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 201
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# … [+3096 chars]Technical analysis isnt a perfect tool, but it may point the way for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Ethereum (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH-USD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>) continues to be a volatile crypto investment.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is volatile by nature Im not setting it apart … [+3612 chars]This enables an L1 platform to bootstrap its national economy over time through a flywheel between financial speculation around its native token and actual building of applications and activities in … [+4057 chars]Coinbase reported that the share of trading volume for ethereum and other altcoins increased
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Between 2020 and 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , ethereum trading volume in… [+1187 chars]People in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Colorado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be able to pay their state taxes in cryptocurrency by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the middle of this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Gov.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jared Polis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  laid out the timing of the move, a longt… [+2206 chars]Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Bareham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br> </br></br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  has been donated so far
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency has been donated to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukrainian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  groups since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  attacked the c… [+7442 chars]It seems that in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , you cant escape from the metaverse. From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]Last night,
# <mark class="entity" style="background: #bfeeb7;

# %%
# List all Entities
for i in ethereum_doc.ents:
    print(i.text, i.label_)
# Out:
# February DATE
# Ethereum Name Service ORG
# ENS ORG
# May 201 DATE
# Ethereum ORG
# ETH-USD ORG
# Crypto PERSON
# last year DATE
# Between 2020 and 2021 DATE
# Colorado GPE
# the middle of this year DATE
# US GPE
# Jared Polis PERSON
# James Bareham PERSON
# More than $15 million MONEY
# More than $15 million MONEY
# Ukrainian GPE
# Russia GPE
# 2022 DATE
# Facebook ORG
# Microsoft ORG
# Twitter PRODUCT
# Ethereum ORG
# second ORDINAL
# two months DATE
# NFT ORG
# 7 CARDINAL
# Reuters ORG
# Monday DATE
# $450 million MONEY
# Sequoia Capital India ORG
# two hours TIME
# YouTube ORG
# Waka Flacka Fla ORG
# the past few years DATE
# NFT ORG
# $23 billion MONEY
# 4 CARDINAL
# Reuters ORG
# 8.82% PERCENT
# 40,611.4 MONEY
# 2202 DATE
# Friday DATE
# 3,291.29 MONEY
# Bitcoin PERSON
# 23.2% PERCENT
# TIME ORG
# weekly DATE
# TIME ORG
# weekly DATE
# 10 CARDINAL
# Reuters ORG
# Thursday DATE
# UK GPE
# today DATE
# Brett Harrison PERSON
# Bitcoin PERSON
# 2017 DATE
# +5776 ORG
# Finance Insider PERSON
# American Express ORG
# Twitter PRODUCT
# Russia GPE
# Ukraine GPE
# Opera ORG
# Keshas PERSON
# Opera ORG
# Monday DATE
# Finance Insider PERSON
# American Express ORG
# Ukrainian NORP
# more than $4 million MONEY
# Russia GPE
# Elliptic LOC
# the year DATE
# Monday DATE
# meme GPE
# token ORG
# 51.12% PERCENT
# 24 hours TIME
# 0.00003492 MONEY
# 1:11 DATE
# Ukraine GPE
# Russia GPE
# Elliptic PRODUCT
# nearly $55 million MONEY
# 11 CARDINAL
# Reuters ORG
# Intel Corp ORG
# Friday DATE
# Bitcoin, Ethereum ORG
# DogeCoin ORG
# Binance PERSON
# June 28, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illus PERSON
# +1327 GPE
# Discord ORG
# Wiki ORG
# FAQs WORK_OF_ART
# Kyiv GPE
# Mykhailo Fedoro PERSON
# chars]MetaMask PRODUCT
# Infura ORG
# two CARDINAL
# Ethereum ORG
# MetaMask PRODUCT
# TWTR PERSON
# -2.03% PERCENT
# Ethereum ORG
# +1.92% PERCENT
# Wednesday DATE
# Twitters Tips ORG
# Bitcoin and Ethereum ORG
# BTCUSD WORK_OF_ART
# +5.43% PERCENT
# ETHUSD ORG
# +4.96% PERCENT
# recent years DATE
# Europe LOC
# Russian NORP
# Ukraine GPE
# Vladimir Putin PERSON
# February 24 DATE
# Ukraine GPE
# Ukraine GPE
# millions CARDINAL
# West LOC
# chars]SoFi Technologies PERSON
# Anthony Noto PERSON
# Noto WORK_OF_ART
# Gucci PERSON
# Italian NORP
# overnight TIME
# more than US$326 million MONEY
# A$457.7 million MONEY
# Ethereum GPE
# two CARDINAL
# at least one CARDINAL
# One CARDINAL
# Sean O'Brien PERSON
# Ukrainian NORP
# Tom Lee PERSON
# Ukraine GPE
# Alex Castro PERSON
# the App Store One FAC
# Jack Dorsey PERSON
# Feb 8 DATE
# Reuters ORG
# Canada GPE
# TMX Group ORG
# first ORDINAL
# 2022 DATE
# April 26-28th DATE
# Dapper Labs PERSON
# Litecoin PERSON
# one CARDINAL
# DApps ORG
# NFT ORG
# Shark Tank WORK_OF_ART
# Kevin O'Leary's PERSON
# 100,000 MONEY
# 200,000 MONEY
# 300,000 MONEY
# Massachusetts Institute of Technology ORG
# MIT ORG
# 2022 DATE
# Ethereum ORG
# MIT ORG
# +3186 ORG
# more than rubles MONEY
# Ukraine GPE
# Mykhailo Fedorov PERSON
# today DATE
# Ukraine GPE
# Russ ORG
# Knox PERSON
# Finance Insider PERSON
# American Express ORG
# American Express ORG
# late 2024 DATE
# one CARDINAL
# Hu PERSON
# Intelligence ORG
# UK GPE
# Russians NORP
# Mark Mobius PERSON
# Russia GPE
# Ukraine GPE
# Thursday DATE
# US GPE
# Ethereum ORG
# Wednesday DATE
# Barter ORG
# +9251 ORG
# just two CARDINAL
# Become a Premium Member ORG
# 3 MONEY
# chars]The Color Museum ORG
# NFT ORG
# Blockchain LOC
# GeForce ORG
# GPU ORG
# Wednesday DATE
# Western NORP
# Russia GPE
# two CARDINAL
# Uk GPE
# The Financial Stab WORK_OF_ART
# two-week DATE
# Tuesday DATE
# Russians NORP
# Ukrainians NORP
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# The United States GPE
# about US$1.1 trillion MONEY
# £830 billion MONEY
# 2003 DATE
# Iraq war EVENT
# UK GPE
# about £2.6 billion MONEY
# Insights Newsletter PERSON
# 724,948 CARDINAL
# tomorrow DATE
# NFT ORG
# Russian NORP
# Ukraine GPE
# the International Space Station ORG
# $20 million MONEY
# $220 million MONEY
# CoinDesk ORG
# Intelligence ORG
# JPMorgan ORG
# first ORDINAL
# Intelligence ORG
# Onyx FAC
# 20 years ago DATE
# Cut Off From Global Economy WORK_OF_ART
# Russia GPE
# Ukraine GPE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# The last few months DATE
# mid-November DATE
# Ethereum(CR GPE
# Ethereum ORG
# Ethereum ORG
# Luis G. Rendon/ PERSON
# Getty ORG
# MAGA ORG
# all 330 trillion MONEY
# Canada GPE
# KPMG ORG
# Bitcoin and Ethereum ORG
# first ORDINAL
# Monday DATE
# Bitcoi ORG
# +1289 ORG
# today DATE
# the Data Summit ORG
# March 9th DATE
# Sadie Williamson PERSON
# Williamson Fintech Consulting ORG
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# Indre Viltrakyte PERSON
# Soviet NORP
# winter DATE
# Bali GPE
# Lithuanian NORP
# last week DATE
# Reuters ORG
# 2022 DATE
# 2.75% PERCENT
# ETH ORG
# two years DATE
# 2017-2019 DATE
# Thursday DATE
# U.S. GPE
# The White House ORG
# hundreds CARDINAL
# Ape Yacht Club ORG
# this week DATE
# two CARDINAL
# 10 CARDINAL
# millions of dollars MONEY
# Thursday DATE
# Federal Reserve ORG
# Jerome Powell PERSON
# ETH ORG
# 77% PERCENT
# the past year DATE
# 3% PERCENT
# the past month DATE
# a rough weekend DATE
# the trading week DATE
# Tuesday DATE
# Russia GPE
# NFT ORG
# OnlyFans NORP
# December DATE
# +615 CARDINAL
# the next decade DATE
# recent days DATE
# 2022 DATE
# 14% PERCENT
# $1.9 trillion MONEY
# year to date DATE
# 13% PERCENT
# $1.9 trillion MONEY
# 2022 DATE

# %% [markdown]
# ---
